# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# **There is an issue showing up in excel. There are cells that appear to be blank but are not counting as blank**
# I have to indidividually copy pasta a blank cell and paste it inside to get it to be blank. I need them blank to be able to use the pivot tables effectively.
# I am going to import the datas into python with pd, and rewrite the files and see if I'm still getting the error. This will save up alot of time for me in the future as I am dealing with a problem right now.

# %%
minidata = pd.read_excel("blank_test_survey.xlsx", sheet_name="MiniData")
minidata.head() #
# Out:
#            ID                Date         Division         Position  \
# 0  5379192392 2021-01-22 12:01:17   Infrastructure            Staff
# 1  2658722536 2021-01-22 06:56:37          Finance            Staff
# 2  4044163394 2021-01-22 06:35:18   Infrastructure  Department Lead
# 3  5535865599 2021-01-21 21:29:32   Infrastructure          Manager
# 4  3356802928 2021-01-21 17:26:39  Port Operations          Manager
#
#      Generation      Gender    Duration Question 1 Response  \
# 0  Generation X        Male   0-2 years                 NaN
# 1           NaN         NaN   10+ years            Answer 4
# 2  Generation X        Male   3-5 years            Answer 5
# 3    Millennial  Non-Binary  5-10 years            Answer 1
# 4  Generation X      Female   10+ years                 NaN
#
#   Question 2 Response Question 3 Open-Ended Response  ...  \
# 0            Answer 6                            NaN  ...
# 1            Answer 2                            NaN  ...
# ...

# %%
print(minidata.columns[39])
print("Index = 39 - " + str(len(minidata.columns)))
# Out:
# Question 11 Reponse 1
# Index = 39 - 93

# %%
copy_data = minidata.iloc[:,39:]
copy_data.head()
# Out:
#   Question 11 Reponse 1 Question 11 Response 2 Question 12 Response  \
# 0                   NaN               Answer 8                  NaN
# 1              Answer 5               Answer 1             Answer 3
# 2              Answer 8               Answer 1                  NaN
# 3                   NaN               Answer 5             Answer 1
# 4              Answer 7                    NaN                  NaN
#
#   Question 13 Response Question 14 Response Question 15 Response  \
# 0                  NaN             Answer 2             Answer 2
# 1                  NaN             Answer 4             Answer 1
# 2             Answer 8             Answer 6                  NaN
# 3             Answer 5                  NaN                  NaN
# 4             Answer 2                  NaN             Answer 5
#
#   Question 16 Response Question 17 Response Question 18 Response  \
# 0             Answer 4             Answer 6             Answer 4
# ...

# %%
x = copy_data
x
# Out:
#     Question 11 Reponse 1 Question 11 Response 2 Question 12 Response  \
# 0                     NaN               Answer 8                  NaN
# 1                Answer 5               Answer 1             Answer 3
# 2                Answer 8               Answer 1                  NaN
# 3                     NaN               Answer 5             Answer 1
# 4                Answer 7                    NaN                  NaN
# ..                    ...                    ...                  ...
# 193              Answer 4               Answer 4             Answer 2
# 194                   NaN               Answer 2                  NaN
# 195                   NaN                    NaN                  NaN
# 196                   NaN               Answer 1             Answer 3
# 197              Answer 8                    NaN                  NaN
#
#     Question 13 Response Question 14 Response Question 15 Response  \
# ...

# %%
x.to_csv("True_blank.csv") ##WRITE THE FILE

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict)
df
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
df.iloc[[0,2],[1,3]]
# Out:
#       b     d
# 0     2     4
# 2  2000  4000

# %%
df.iloc[:,2:]
# Out:
#       c     d
# 0     3     4
# 1   300   400
# 2  3000  4000
